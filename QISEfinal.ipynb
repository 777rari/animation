# %% [markdown]
# # Define a qubit and explain the difference between a classical bit and a qubit.

# %%
print('A qubit is unit of quantum information and is a building block for quaantum computing. Electron spin can be used to represent a one or zero of a qubit')
print('A qubit can be in a state between 0 or 1, differing from a classical bit which can only be 0 or 1')
# Out:
# A qubit is unit of quantum information and is a building block for quaantum computing. Electron spin can be used to represent a one or zero of a qubit
# A qubit can be in a state between 0 or 1, differing from a classical bit which can only be 0 or 1

# %% [markdown]
# # Explain the concept of superposition in quantum computing

# %%
print('In quantum computing, superposition is way of saying that a qubit is in a linear combination of states')
# Out:
# In quantum computing, superposition is way of saying that a qubit is in a linear combination of states

# %% [markdown]
# # Describe the process of measurement in quantum computing and its effect on a qubit.

# %%
print('Measurement is used to find the probability of a qubit being either 0 or 1')
# Out:
# Measurement is used to find the probability of a qubit being either 0 or 1

# %% [markdown]
# # What is a quantum gate? Provide an example of a single qubit gate and explain its operation.

# %%
print('A quantum gate is a mathematical operator that is typically repesented by a matrix. The gates act on qubits to perform a specific operation')
print('An a example of a quantum gate is a pauli X-Gate, which is the quantum equivalent of a classical NOT gate')
# Out:
# A quantum gate is a mathematical operator that is typically repesented by a matrix. The gates act on qubits to perform a specific operation
# An a example of a quantum gate is a pauli X-Gate, which is the quantum equivalent of a classical NOT gate

# %% [markdown]
# # Explain the following matrix operations and describe their relevance to quantum computing:
# # a. matrix multiplication
# # b. transpose
# # c. conjugate
# # d. hermitian conjugate

# %%
print('Matrix multiplication is taking the dot product of two matrices and can be used to describe the actions of quantum gates on quantum state')
# Out:
# Matrix multiplication is taking the dot product of two matrices and can be used to describe the actions of quantum gates on quantum state

# %%
print('Transpose is the term used to describe when a matrix has its rows and columns and is used to describe the hermitian conjugate of a quantum gate')
# Out:
# Transpose is the term used to describe when a matrix has its rows and columns and is used to describe the hermitian conjugate of a quantum gate

# %%
print('Conjugate is when you change the sign of your equation and is used in quantum computing to calculate the probability of getting certain measuremnts')
# Out:
# Conjugate is when you change the sign of your equation and is used in quantum computing to calculate the probability of getting certain measuremnts

# %%
print('The hermitian conjugate is a transpose of the complex conjugate of a matrix and is used to calculate probabilities of an outcome of a measurement')
# Out:
# The hermitian conjugate is a transpose of the complex conjugate of a matrix and is used to calculate probabilities of an outcome of a measurement

# %% [markdown]
# # Describe the Bloch sphere and explain how it is used to visualize quantum states.

# %%
print('Bloch spheres are tools used to visually represent a qubit state. It is a mathematical representation of the qubit state that can be used to understand and manipulate a qubit state. Any quantum state of the qubit can be represented by a point on the surface of the sphere.')
# Out:
# Bloch spheres are tools used to visually represent a qubit state. It is a mathematical representation of the qubit state that can be used to understand and manipulate a qubit state. Any quantum state of the qubit can be represented by a point on the surface of the sphere.

# %% [markdown]
# #  Define entanglement and provide an example of an entangled state.

# %%
print('Entanglement is when qubits exists in a single quantum state and an example of an entangled')
# Out:
# Entanglement is when qubits exists in a single quantum state and an example of an entangled

# %%
from qiskit import *
bellCirc=QuantumCircuit(2,2)
bellCirc.x(0)
bellCirc.h(0)
bellCirc.cnot(0,1)
bellCirc.measure(range(2), range(2))
backend_sim = Aer.get_backend('qasm_simulator')
job_sim = backend_sim.run(transpile(bellCirc, backend_sim), shots=1024)
result_sim = job_sim.result()
counts = result_sim.get_counts(bellCirc)
print(counts)
bellCirc.draw(output='mpl')
# Out:
# {'00': 519, '11': 505}

# %% [markdown]
# # Explain the concept of tensor product in relation to multi-qubit states and gates. Provide an example of a multi-qubit gate.

# %%
print('Tensor product is a mathematical operation used to combine two or more qubits into a single-qubit system')
# Out:
# Tensor product is a mathematical operation used to combine two or more qubits into a single-qubit system

# %%
from qiskit import *
import qiskit.quantum_info as qi
import numpy as np
circ = QuantumCircuit(3,3)
circ.h(0)
circ.x(1)
circ.z(2)
circ.draw(output='mpl')

# %% [markdown]
# # Given the following 2-qubit state: |01⟩, explicitly calculate the tensor product of the individual qubits and write the 2-qubit state as a vector.

# %%
from qiskit import *
import numpy as np
circ = QuantumCircuit(2,2)
circ.x(0)
circ.z(1)

circ.draw(output='mpl')

# %%
backend = Aer.get_backend('statevector_simulator')
job = backend.run(circ)
result = job.result()
outputstate = result.get_statevector(circ, decimals=3)
print(outputstate)
outputstate.draw('latex')
# Out:
# Statevector([ 0.+0.j,  1.+0.j, -0.+0.j, -0.+0.j],
#             dims=(2, 2))
# $$ |01\rangle$$

# %% [markdown]
# # Explain the concept of a quantum circuit and how it is used to represent quantum computations.

# %%
print('A quantum circuit is a graphical representation of a quantum computation and represents how the qubit evolves')
# Out:
# A quantum circuit is a graphical representation of a quantum computation and represents how the qubit evolves

# %% [markdown]
# # Given the following quantum circuit, write the corresponding qiskit code to create and draw it.

# %%
from qiskit import *
from math import pi
circ = QuantumCircuit(1,1)
circ.x(0)
circ.rx(pi,0)
circ.draw(output='mpl')

# %% [markdown]
# # Using qiskit, create a quantum circuit with two qubits. Apply an X gate to the first qubit and a Hadamard gate to the second qubit. Draw the circuit.

# %%
from qiskit import *
from math import pi
circ = QuantumCircuit(2,2)
circ.x(0)
circ.h(1)
circ.draw(output='mpl')

# %% [markdown]
# #  Explain the difference between qiskit’s statevectorsimulator and qasmsimulator backends. When would you choose to use one over the other?

# %%
print('The qasm_simulator simulates the measurement process using a probalistic approach to mimic a real world quantum computer while the statevector_simulator calculates the statevector using matrix multiplication to mimic a noiseless quantum computer')
# Out:
# The qasm_simulator simulates the measurement process using a probalistic approach to mimic a real world quantum computer while the statevector_simulator calculates the statevector using matrix multiplication to mimic a noiseless quantum computer

# %%
print('If you want the exact state of a quantum circuit you would use the statevector simulator and if you wanted to simulate noise and error you would use the qasm_simulator')
# Out:
# If you want the exact state of a quantum circuit you would use the statevector simulator and if you wanted to simulate noise and error you would use the qasm_simulator

# %% [markdown]
# # Using qiskit, create a quantum circuit that generates a Bell state. Run the circuit using the qasmsimulator backend, and print the measurements counts.

# %%
from qiskit import *
qc = QuantumCircuit(2,2)
qc.h(0)
qc.cx(0, 1)
qc.measure([0, 1], [0, 1])
qc.draw(output='mpl')
backend = Aer.get_backend('qasm_simulator')
job = execute(qc, backend, shots=1024)
result = job.result()
print(result.get_counts())
# Out:
# {'11': 529, '00': 495}

# %% [markdown]
# # Coding Question 5

# %%
from qiskit import *
from qiskit.visualization import plot_bloch_multivector
circ = QuantumCircuit(1)
circ.h(0)
backend = Aer.get_backend('statevector_simulator')
job = execute(circ, backend)
result = job.result()
statevector = result.get_statevector()
plot_bloch_multivector(statevector)
